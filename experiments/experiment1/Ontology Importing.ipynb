# %%
# %%bash
# pwd
# Out:
# /home/lis/matheus/jupyter/phd_old

# %%
# %matplotlib inline 

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import nltk
from bs4 import BeautifulSoup

import requests

url = "uol.com.br"

r  = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data,"html5lib")
text = soup.get_text(data)

cleaned = nltk.word_tokenize(text.lower())
wordlist = [x for x in cleaned if (len(x)>=5 and x.isalpha())]
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white').generate(" ".join(wordlist))
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import sys

print (sys.maxsize)
# Out:
# 9223372036854775807
